# %%
import asyncio,time

# %%
def f1(num):
    print('start',num)
    time.sleep(1)
    print('end',num)

# %%
start=time.time()
f1(1)
f1(2)
f1(3)
end=time.time()
print(end-start)
# Out:
# start 1
# end 1
# start 2
# end 2
# start 3
# end 3
# 3.003222703933716

# %%
## the comes async await 

# this is the best part as now , 

@app.get()
async def func():
    await request()
